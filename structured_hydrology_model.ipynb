# %%
#defining functions for later processing and feature enggimport pandas as pd
from itertools import product

#####
from sklearn.linear_model import LinearRegression
def create_lag(df, lag_sca, lag_dd, lag_precip, lag_et):
    df['sca_lagged'] = df['sca'].shift(lag_sca)
    df['dd_lagged'] = df['dd'].shift(lag_dd)
    df['et_loss_lagged'] = df['et_loss'].shift(lag_et)
    df['melt_proxy'] = df['sca_lagged']*df['dd_lagged']
    df['precipitation_lagged'] = df['precipitation'].shift(lag_precip)
    # df['precipitation_lagged-1'] = df['precipitation'].shift(lag_precip-1)
    # df['precipitation_lagged_cum'] = ((df['precipitation']+df['precipitation_lagged'])/2)
    
    df_clean = df.dropna()
    return df_clean

#####
import numpy as np
def calculate_nse(observed, predicted):
    mean_obs = np.mean(observed)
    numerator = np.sum((observed - predicted) ** 2)
    denominator = np.sum((observed - mean_obs) ** 2)
    return 1 - (numerator / denominator)

# %% [markdown]
# # Step 1 – Data Import & Exploration
# Import the dataset and examine its structure, dimensions, data types, and data quality before any analysis.

# %%
# Cell 1 – Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import missingno as msno

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

def rmse(predictions, targets):
    return np.sqrt(mean_squared_error(predictions, targets))

# %%
# Cell 2 – Load & Explore Dataset
import pandas as pd
df1 = pd.read_csv('final_data_physics_baseline/phy_final_corrected_data.csv')
pd.to_datetime(df1['date'])
df1 = df1.set_index('date')
df1.drop(columns= 'Unnamed: 0', inplace= True)
df1.drop(columns= 'Unnamed: 0.1', inplace= True)

# we convert 0-12 to radians circle for a seasonal mapping (circular time encoding)
# ensure index is treated as datetime (works even if the Index is not recognized as DatetimeIndex)
import numpy as np
month = pd.DatetimeIndex(df1.index).month

df1['year_sin'] = np.sin(2*np.pi*month/12)
df1['year_cos'] = np.cos(2*np.pi*month/12)


df = df1.copy()
df.head()
# Out:
#               dewpoint   et_loss      ndvi  precipitation    radiation  \
# date
# 2000-06-30  270.274111  0.035384  0.167895       1.081265  8552.215167
# 2000-07-31  275.634907  0.005471  0.214835       2.074423  8945.476526
# 2000-08-31  273.643363  0.016486  0.171795       1.208544  8787.250911
# 2000-09-30  266.780844  0.040531  0.148384       0.857759  7687.016192
# 2000-10-31  259.412862  0.029951  0.113129       0.231264  5685.865842
#
#                      sca        dd        temp    runoff      year_sin  \
# date
# 2000-06-30  15695.091988  0.000000  255.924696  0.959289  1.224647e-16
# 2000-07-31   6188.434963  0.000000  253.865719  0.515886 -5.000000e-01
# 2000-08-31  10114.130241  0.000000  258.913569  0.355015 -8.660254e-01
# 2000-09-30  12888.810599  0.000000  265.094486  0.186357 -1.000000e+00
# 2000-10-31  19583.623736  0.551964  273.551964  0.138155 -8.660254e-01
#
#                 year_cos
# date
# 2000-06-30 -1.000000e+00
# 2000-07-31 -8.660254e-01
# 2000-08-31 -5.000000e-01
# 2000-09-30 -1.836970e-16
# 2000-10-31  5.000000e-01

# %%
# Describe numerical columns
display(df1.describe())
# Out:
#          dewpoint       et_loss        ndvi  precipitation    radiation  \
# count  306.000000  3.060000e+02  306.000000     306.000000   306.000000
# mean   260.204040  4.897667e-02    0.281527       0.899558  4766.153318
# std      9.356982  3.407956e-02    0.125110       0.786415  2687.884601
# min    244.182792  1.233960e-11    0.060334       0.024735  1169.768120
# 25%    251.695580  2.163164e-02    0.172804       0.298468  2214.416509
# 50%    259.381040  4.165413e-02    0.240190       0.698135  4171.281813
# 75%    268.515510  7.125847e-02    0.393557       1.214406  7369.761084
# max    276.245179  1.488600e-01    0.546876       4.527822  9759.438905
#
#                 sca          dd        temp      runoff      year_sin  \
# count    306.000000  306.000000  306.000000  306.000000  3.060000e+02
# mean   28064.896687    1.973379  267.537885    0.503403 -1.219624e-02
# std    12115.442127    3.266650    9.414784    0.723346  7.081597e-01
# min     5300.632089    0.000000  252.447712    0.029289 -1.000000e+00
# 25%    18397.686028    0.000000  258.834349    0.063727 -8.660254e-01
# 50%    27202.299004    0.000000  266.584307    0.151048 -2.449294e-16
# 75%    36316.956525    3.477651  276.477651    0.622741  5.000000e-01
# max    60577.019749   10.742527  283.742527    3.351402  1.000000e+00
#
#            year_cos
# count  3.060000e+02
# mean  -3.267974e-03
# std    7.082575e-01
# min   -1.000000e+00
# 25%   -7.745191e-01
# 50%   -1.836970e-16
# 75%    5.000000e-01
# max    1.000000e+00

# %% [markdown]
# # Step 2 – Visualise Missing Values

# %%
# Cell 3 – Missing Value Matrix
# Visualize missing values as a matrix
msno.matrix(df1)
plt.title('Missing Value Matrix', fontsize=16)
plt.show()

# %% [markdown]
# # Step 3 – Data Manipulation & Feature Engineering
# Clean the dataset, drop unnecessary columns, fix data types, and create analysis-ready features.

# %%
# Cell 4 – Feature Engineering with Lagged Variables
def create_lag_adv_corrected(df_in):
    """
    Creates advanced lagged features WITHOUT data leakage.
    - Uses a copy to avoid modifying the original dataframe.
    - Enforces a minimum lag of 1 to prevent using current-day info.
    """
    df = df_in.copy() # Work on a copy to prevent side effects

    for i in range(1, 8):
        df[f'sca_lagged_{i}'] = df['sca'].shift(i)
        df[f'dd_lagged_{i}'] = df['dd'].shift(i)
    df['et_loss_lagged_1'] = df['et_loss'].shift(1)
    df['precipitation_lagged_1'] = df['precipitation'].shift(1)

    for i in range(1,8):
        for j in range(1,8):
            if i >= j and i - j < 2:
                df[f'melt_proxy_{i}_{j}'] = df[f'sca_lagged_{i}'] * df[f'dd_lagged_{j}']
    
    
    return df.dropna()

# %% [markdown]
# # Step 4 – Exploratory Data Analysis
# Visualise distributions, correlations, and patterns to understand how features relate to the runoff target.

# %%
# Cell 5 - Time Series Plot of Runoff
px.line(df1, y='runoff', title='Monthly Runoff at Tarbela')

# %%
# Cell 6 - Plotting other key variables
fig = make_subplots(rows=3, cols=1, shared_xaxes=True, subplot_titles=('Precipitation', 'Temperature', 'Snow Covered Area (SCA)'))
fig.add_trace(go.Scatter(x=df.index, y=df['precipitation'], mode='lines', name='Precipitation'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df['temp'], mode='lines', name='Temperature'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df['sca'], mode='lines', name='SCA'), row=3, col=1)
fig.update_layout(height=600, title_text="Key Climate Variables Over Time")
fig.show()

# %%
import numpy as np

# Cell 7 – Correlation Heatmap
plt.figure(figsize=(14, 12))
# full correlation matrix between all numeric features
corr = df.corr()

# mask the upper triangle for readability
# mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1, linewidths=0.5)
plt.title('Feature Correlation Matrix (pairwise)')
plt.show()

# %% [markdown]
# # Step 5 – Data Preprocessing & Baseline Model

# %%
# Cell 8 – Train-Validation-Test Split
#train baseline prediction regression model only fitted on train data
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# --- FIX: Prevent data leakage by splitting BEFORE creating lagged features ---

# 1. Split the raw dataframe first
train_raw = df[:'2017-12-31']
val_raw = df['2018-01-01':'2021-12-31']
test_raw = df['2022-01-01':]

# 2. Apply the lag function to each split independently
x_train = create_lag(train_raw, lag_precip=1, lag_dd=3, lag_sca=3, lag_et=1)
x_val = create_lag(val_raw, lag_precip=1, lag_dd=3, lag_sca=3, lag_et=1)
x_test = create_lag(test_raw, lag_precip=1, lag_dd=3, lag_sca=3, lag_et=1)

# 3. Create feature and target sets from the leakage-free dataframes
X_train_lagged = x_train[['sca_lagged','dd_lagged','year_sin', 'year_cos', 'melt_proxy', 'et_loss_lagged', 'precipitation_lagged']]
Y_train_lagged = x_train[['runoff']]

X_val_lagged = x_val[['sca_lagged','dd_lagged','year_sin', 'year_cos', 'melt_proxy', 'et_loss_lagged', 'precipitation_lagged']]
Y_val_lagged = x_val[['runoff']]

X_test_lagged = x_test[['sca_lagged','dd_lagged','year_sin', 'year_cos', 'melt_proxy', 'et_loss_lagged', 'precipitation_lagged']]
Y_test_lagged = x_test[['runoff']]

X_train_val = pd.concat([X_train_lagged, X_val_lagged])
Y_train_val = pd.concat([Y_train_lagged, Y_val_lagged])

# %%
from sklearn.metrics import r2_score

# Cell 9 - Linear Regression Model
# Define features (X) and target (y)
seasonaware_model = LinearRegression()
seasonaware_model.fit(X_train_lagged, Y_train_lagged)

y_test_pred = seasonaware_model.predict(X_test_lagged)
baseline_nse = calculate_nse(Y_test_lagged, y_test_pred)
print(f"Baseline NSE: {baseline_nse}")

print("Linear Regression Coefficients:")
print(seasonaware_model.coef_)

# Evaluate the model
r2_lr = r2_score(Y_test_lagged.values.ravel(), y_test_pred.ravel())
print(f'Linear Regression R-squared: {r2_lr:.4f}')

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(x_test.index, Y_test_lagged, label='Actual Discharge')
plt.plot(x_test.index, y_test_pred, label='Predicted Discharge (LR)', linestyle='--')
plt.title('Linear Regression: Actual vs. Predicted Discharge')
plt.xlabel('Date')
plt.ylabel('Discharge')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Baseline NSE: runoff    0.684799
# dtype: float64
# Linear Regression Coefficients:
# [[ 2.16269601e-06 -1.27239269e-01  1.68094217e-01 -7.78212851e-01
#    7.67360800e-08  5.11143655e+00 -1.17883239e-01]]
# Linear Regression R-squared: 0.6848

# %%
# --- FIX: Create a clean, leakage-free dataframe for the hybrid model ---

# 1. Get baseline predictions for each split
train_preds = seasonaware_model.predict(X_train_lagged)
val_preds = seasonaware_model.predict(X_val_lagged)
test_preds = seasonaware_model.predict(X_test_lagged)

# 2. Combine baseline predictions and residuals into a single dataframe
baseline_results = pd.concat([
    pd.DataFrame({'baseline_q': train_preds.ravel(), 'runoff': Y_train_lagged.runoff}, index=X_train_lagged.index),
    pd.DataFrame({'baseline_q': val_preds.ravel(), 'runoff': Y_val_lagged.runoff}, index=X_val_lagged.index),
    pd.DataFrame({'baseline_q': test_preds.ravel(), 'runoff': Y_test_lagged.runoff}, index=X_test_lagged.index)
])
baseline_results['residuals'] = baseline_results['runoff'] - baseline_results['baseline_q']

# 3. Create advanced lagged features on the original raw data (no leakage yet)
df_adv_features = create_lag_adv_corrected(df1)

# 4. Join the baseline results with the advanced features
# This aligns everything by date index before the final split
df_adv = df_adv_features.join(baseline_results[['baseline_q', 'residuals']]).dropna()

# Add seasonal features back in
# df_adv['year_sin'] = df1['year_sin']
# df_adv['year_cos'] = df1['year_cos']
df_adv.dropna(inplace=True)

df_adv.head()
# Out:
#               dewpoint   et_loss      ndvi  precipitation    radiation  \
# date
# 2001-01-31  245.385546  0.043346  0.312486       0.063452  1916.205105
# 2001-02-28  249.247312  0.035878  0.277432       0.122006  1990.003765
# 2001-03-31  250.238542  0.092487  0.316421       0.349344  3030.571862
# 2001-04-30  259.390017  0.095070  0.355468       0.510792  3730.624551
# 2001-05-31  263.825858  0.065791  0.191359       0.413804  6587.419005
#
#                      sca        dd        temp    runoff  year_sin  ...  \
# date                                                                ...
# 2001-01-31  35286.368770  7.745643  280.745643  0.041160  0.500000  ...
# 2001-02-28  25131.303245  3.499669  276.499669  0.033957  0.866025  ...
# 2001-03-31  46124.160931  0.000000  268.727686  0.042010  1.000000  ...
# 2001-04-30  34841.225052  0.000000  261.426247  0.152912  0.866025  ...
# 2001-05-31  37103.592715  0.000000  255.821086  1.180436  0.500000  ...
#
#             melt_proxy_4_3  melt_proxy_4_4  melt_proxy_5_4  melt_proxy_5_5  \
# date
# 2001-01-31     7114.156644        0.000000        0.000000        0.000000
# 2001-02-28   103227.834953    10809.451022     7114.156644        0.000000
# 2001-03-31   201989.936303   111661.909735   103227.834953    10809.451022
# 2001-04-30   285835.917089   351874.477600   201989.936303   111661.909735
# 2001-05-31   123490.610497   273315.614884   285835.917089   351874.477600
#
#             melt_proxy_6_5  melt_proxy_6_6  melt_proxy_7_6  melt_proxy_7_7  \
# date
# 2001-01-31        0.000000        0.000000        0.000000        0.000000
# 2001-02-28        0.000000        0.000000        0.000000        0.000000
# 2001-03-31     7114.156644        0.000000        0.000000        0.000000
# 2001-04-30   103227.834953    10809.451022     7114.156644        0.000000
# 2001-05-31   201989.936303   111661.909735   103227.834953    10809.451022
#
#             baseline_q  residuals
# date
# 2001-01-31    0.058373  -0.017213
# 2001-02-28   -0.082994   0.116951
# 2001-03-31   -0.206568   0.248578
# 2001-04-30    0.640744  -0.487832
# 2001-05-31    1.362304  -0.181868
#
# [5 rows x 42 columns]

# %%
# df_adv = create_lag_adv_corrected(df1) 
# df_adv = df_adv.join(df_full[['baseline_q', 'residuals']]).dropna()
# df_adv.head()
# df_adv['year_sin'] = x_lagged['year_sin']
# df_adv['year_cos'] = x_lagged['year_cos']
col_names = df_adv.columns.tolist()
col_names
# Out:
# ['dewpoint',
#  'et_loss',
#  'ndvi',
#  'precipitation',
#  'radiation',
#  'sca',
#  'dd',
#  'temp',
#  'runoff',
#  'year_sin',
#  'year_cos',
#  'sca_lagged_1',
#  'dd_lagged_1',
#  'sca_lagged_2',
#  'dd_lagged_2',
#  'sca_lagged_3',
#  'dd_lagged_3',
#  'sca_lagged_4',
#  'dd_lagged_4',
#  'sca_lagged_5',
#  'dd_lagged_5',
#  'sca_lagged_6',
#  'dd_lagged_6',
#  'sca_lagged_7',
#  'dd_lagged_7',
#  'et_loss_lagged_1',
#  'precipitation_lagged_1',
#  'melt_proxy_1_1',
#  'melt_proxy_2_1',
#  'melt_proxy_2_2',
#  'melt_proxy_3_2',
#  'melt_proxy_3_3',
#  'melt_proxy_4_3',
#  'melt_proxy_4_4',
#  'melt_proxy_5_4',
#  'melt_proxy_5_5',
#  'melt_proxy_6_5',
#  'melt_proxy_6_6',
#  'melt_proxy_7_6',
#  'melt_proxy_7_7',
#  'baseline_q',
#  'residuals']

# %% [markdown]
# # Step 6 – Train Hybrid Models
# Train more advanced models on the residuals of the baseline model.

# %%
# Cell 10 - XGBoost Model Data Preparation

import pandas as pd

# --- FIX: Dynamically define features from the corrected df_adv to prevent leakage ---

# 1. Define target and baseline columns to be excluded from features
target_and_baseline_cols = ['runoff', 'baseline_q', 'residuals','ndvi', 'dewpoint', 'dd','temp','sca','precipitation', 'year_cos', 'year_sin', 'radiation','et_loss',]
feature_columns = [col for col in df_adv.columns if col not in target_and_baseline_cols]

# 2. Split the fully prepared and leakage-free dataframe
train_ml = df_adv[:'2017-12-31']
val_ml = df_adv['2018-01-01':'2021-12-31']
test_ml = df_adv['2022-01-01':]

# 3. Prepare features (X) and labels (y) for the hybrid model
X_train_ml = train_ml[feature_columns]
y_train_ml = train_ml['residuals']

X_val_ml = val_ml[feature_columns]
y_val_ml = val_ml['residuals']

X_test_ml = test_ml[feature_columns]
y_test_ml = test_ml['residuals']

# Display the first few rows of the training features to verify
X_train_ml.head()
# Out:
#             sca_lagged_1  dd_lagged_1  sca_lagged_2  dd_lagged_2  \
# date
# 2001-01-31  36902.800385     9.535170  21183.674218     5.271130
# 2001-02-28  35286.368770     7.745643  36902.800385     9.535170
# 2001-03-31  25131.303245     3.499669  35286.368770     7.745643
# 2001-04-30  46124.160931     0.000000  25131.303245     3.499669
# 2001-05-31  34841.225052     0.000000  46124.160931     0.000000
#
#             sca_lagged_3  dd_lagged_3  sca_lagged_4  dd_lagged_4  \
# date
# 2001-01-31  19583.623736     0.551964  12888.810599     0.000000
# 2001-02-28  21183.674218     5.271130  19583.623736     0.551964
# 2001-03-31  36902.800385     9.535170  21183.674218     5.271130
# 2001-04-30  35286.368770     7.745643  36902.800385     9.535170
# 2001-05-31  25131.303245     3.499669  35286.368770     7.745643
#
#             sca_lagged_5  dd_lagged_5  ...  melt_proxy_3_2  melt_proxy_3_3  \
# date                                   ...
# 2001-01-31  10114.130241     0.000000  ...   103227.834953    10809.451022
# 2001-02-28  12888.810599     0.000000  ...   201989.936303   111661.909735
# 2001-03-31  19583.623736     0.551964  ...   285835.917089   351874.477600
# 2001-04-30  21183.674218     5.271130  ...   123490.610497   273315.614884
# 2001-05-31  36902.800385     9.535170  ...        0.000000    87951.242605
#
#             melt_proxy_4_3  melt_proxy_4_4  melt_proxy_5_4  melt_proxy_5_5  \
# date
# 2001-01-31     7114.156644        0.000000        0.000000        0.000000
# 2001-02-28   103227.834953    10809.451022     7114.156644        0.000000
# 2001-03-31   201989.936303   111661.909735   103227.834953    10809.451022
# 2001-04-30   285835.917089   351874.477600   201989.936303   111661.909735
# 2001-05-31   123490.610497   273315.614884   285835.917089   351874.477600
#
#             melt_proxy_6_5  melt_proxy_6_6  melt_proxy_7_6  melt_proxy_7_7
# date
# 2001-01-31        0.000000        0.000000        0.000000        0.000000
# 2001-02-28        0.000000        0.000000        0.000000        0.000000
# 2001-03-31     7114.156644        0.000000        0.000000        0.000000
# 2001-04-30   103227.834953    10809.451022     7114.156644        0.000000
# 2001-05-31   201989.936303   111661.909735   103227.834953    10809.451022
#
# [5 rows x 29 columns]

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# Define the parameter grid
# You can expand this grid to tune other parameters as well
param_grid = {
    'max_depth': [3, 4, 5, 6, 7],
    'n_estimators': range(500,1100, 100),
    'learning_rate': [0.01, 0.1, 0.2]
}

# Initialize the XGBoost regressor
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV
# We use 'neg_root_mean_squared_error' as the scoring metric.
# GridSearchCV maximizes the score, so it minimizes RMSE.
grid_search = GridSearchCV(estimator=xgb_reg, param_grid=param_grid, 
                           cv=3, n_jobs=-1, verbose=2, scoring='neg_root_mean_squared_error')

# Fit GridSearchCV
# Note: This can take some time to run
grid_search.fit(X_train_ml, y_train_ml)

# Print the best parameters found
print(f"Best parameters found: {grid_search.best_params_}")

# You can now use the best estimator for prediction
best_xgb_model = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 90 candidates, totalling 270 fits
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=600; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=600; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=700; total time=   0.4s[CV] END ..learning_rate=0.01, max_depth=3, n_estimators=700; total time=   0.4s
#
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=600; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=800; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=800; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=900; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=900; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.5s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=900; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.7s
# [CV] END .learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=600; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=600; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=700; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=600; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=700; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=700; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=800; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=800; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=800; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=900; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=900; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=900; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.7s
# [CV] END .learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.9s
# [CV] END .learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   1.0s
# [CV] END .learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=600; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=600; total time=   1.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=600; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=700; total time=   1.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=700; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=700; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=800; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=800; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=800; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=900; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=900; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=900; total time=   1.8s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=500; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=500; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=500; total time=   1.3s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.9s
# [CV] END .learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.8s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=600; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=600; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=600; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=700; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=700; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=700; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=800; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=800; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=800; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=900; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=900; total time=   1.8s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=900; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=   1.2s
# [CV] END .learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=   1.2s
# [CV] END .learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=600; total time=   1.2s
# [CV] END .learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=600; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=600; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=700; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=700; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=700; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=800; total time=   1.7s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=800; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=800; total time=   1.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=600; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=900; total time=   2.1s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=900; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=900; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=900; total time=   0.4s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   2.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=900; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=900; total time=   0.5s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   2.3s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END .learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=900; total time=   0.4s
# [CV] END ..learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END ..learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END ..learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=700; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=800; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=800; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=900; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=900; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=900; total time=   0.5s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.5s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.4s
# [CV] END ..learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=700; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=700; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=800; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=800; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=800; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=900; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=900; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=900; total time=   0.7s
# [CV] END ..learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END ..learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.6s
# [CV] END ..learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=600; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=700; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=800; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=800; total time=   0.5s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=900; total time=   0.5s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=900; total time=   0.6s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.6s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=900; total time=   0.6s
# [CV] END ..learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=700; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=900; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=3, n_estimators=1000; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=900; total time=   0.5s
# [CV] END ..learning_rate=0.2, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=900; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=900; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END ...learning_rate=0.2, max_depth=4, n_estimators=900; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END ..learning_rate=0.2, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=600; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=900; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=800; total time=   0.5s
# [CV] END ..learning_rate=0.2, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.2, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=6, n_estimators=900; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=500; total time=   0.2s
# [CV] END ..learning_rate=0.2, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=500; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=500; total time=   0.3s
# [CV] END ..learning_rate=0.2, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=600; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=700; total time=   0.2s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=600; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=6, n_estimators=1000; total time=   0.6s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=700; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=800; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=800; total time=   0.4s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=900; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=900; total time=   0.3s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=900; total time=   0.4s
# [CV] END ..learning_rate=0.2, max_depth=7, n_estimators=1000; total time=   0.3s
# [CV] END ..learning_rate=0.2, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END ..learning_rate=0.2, max_depth=7, n_estimators=1000; total time=   0.3s
# Best parameters found: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}

# %%
# --- Now proceed with the corrected dataframe ---
from sklearn.metrics import r2_score
from xgboost import XGBRegressor

# --- Try a simpler XGBoost model ---
xgb2 = XGBRegressor(
    max_depth=3,
    learning_rate=0.01, # Slightly higher learning rate
    n_estimators=500,   # Fewer estimators
    random_state=42
)

# 3. Fit the model ONLY on the training data
xgb2.fit(X_train_ml, y_train_ml)

# 4. Predict on the validation set
residual_pred_val = xgb2.predict(X_val_ml)
q_hybrid_val = residual_pred_val + val_ml['baseline_q']

# 5. Evaluate against the correct validation ground truth
y_val_true = val_ml['runoff']
hybrid_nse_val = calculate_nse(y_val_true, q_hybrid_val)

print(f"Corrected Hybrid NSE (Validation): {hybrid_nse_val:.4f}")

# --- Final Test Set Evaluation ---
# Prepare combined training/validation data
X_train_val_ml = pd.concat([X_train_ml, X_val_ml])
y_train_val_ml = pd.concat([y_train_ml, y_val_ml])

# Prepare test data
X_test_ml = test_ml.drop(columns=target_and_baseline_cols)

# Re-fit the model on all available training data
xgb2.fit(X_train_val_ml, y_train_val_ml)

# Predict on the test set
residual_pred_test = xgb2.predict(X_test_ml)
q_hybrid_test = residual_pred_test + test_ml['baseline_q']

# Evaluate against the test ground truth
y_test_true = test_ml['runoff']
hybrid_nse_test = calculate_nse(y_test_true, q_hybrid_test)

print(f"Final Hybrid NSE (Test): {hybrid_nse_test:.4f}")

# Compute R² for validation and test hybrid predictions
r2_val = r2_score(y_val_true, q_hybrid_val)
r2_test = r2_score(y_test_true, q_hybrid_test)

print(f'Validation R² (Hybrid XGB): {r2_val:.4f}')
print(f'Test R² (Hybrid XGB):       {r2_test:.4f}')
# Plot Validation and Test: Observed vs Baseline vs Hybrid
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(14, 10), sharex=False)

# Validation plot
axes[0].plot(val_ml.index, df.loc[val_ml.index, 'runoff'], label='Observed (Val)', color='black', linewidth=2)
axes[0].plot(val_ml.index, val_ml['baseline_q'], label='Baseline (Val)', linestyle='--', alpha=0.8)
axes[0].plot(val_ml.index, q_hybrid_val, label='Hybrid XGB (Val)', linestyle='-.', alpha=0.9)
axes[0].set_title(f'Validation: Observed vs Baseline vs Hybrid  |  NSE (Hybrid) = {hybrid_nse_val:.3f}')
axes[0].set_ylabel('Runoff')
axes[0].legend()
axes[0].grid(True)

# Test plot
axes[1].plot(test_ml.index, df.loc[test_ml.index, 'runoff'], label='Observed (Test)', color='black', linewidth=2)
axes[1].plot(test_ml.index, test_ml['baseline_q'], label='Baseline (Test)', linestyle='--', alpha=0.8)
axes[1].plot(test_ml.index, q_hybrid_test, label='Hybrid XGB (Test)', linestyle='-.', alpha=0.9)
axes[1].set_title(f'Test: Observed vs Baseline vs Hybrid  |  NSE (Hybrid) = {hybrid_nse_test:.3f}')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Runoff')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# Corrected Hybrid NSE (Validation): 0.7278
# Final Hybrid NSE (Test): 0.6952
# Validation R² (Hybrid XGB): 0.7278
# Test R² (Hybrid XGB):       0.6952

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.stattools import durbin_watson

fig, axes = plt.subplots(1,2, figsize= (18, 4))
# plot_acf( residual_pred_valf, lags = 12, ax = axes[0], title = 'val_acf' )
plot_acf( test_ml['residuals'], lags = 12, ax = axes[1], title = 'test_acf' )
plot_acf(residual_pred_test, lags=12, ax=axes[0], title='baseline_acf')

plt.savefig('acf_residuals.png', dpi=150)
plt.show()

# 2. Durbin-Watson statistic (quick scalar check)
dw_baseline = durbin_watson(test_ml['residuals'])
dw_hybrid   = durbin_watson(residual_pred_test)

print(f"Durbin-Watson — Baseline: {dw_baseline:.3f} | Hybrid: {dw_hybrid:.3f}")
# ~2.0 = no autocorrelation, <1.5 = positive autocorrelation (bad), >2.5 = negative
# Out:
# Durbin-Watson — Baseline: 1.753 | Hybrid: 2.126

# %% [markdown]
# # Step 7 – Evaluate & Visualise Results
# Compare performance across models and visualise the predictions against the observed data.

# %%
# Cell 13 - Create a results DataFrame for plotting (use actual names from this notebook)
# Observed: y_test_true (test ground truth)
# Baseline: y_test_pred (baseline LR predictions on X_test_lagged) -> flatten and align index
# Hybrid_XGB: q_hybrid_test (final hybrid XGB predictions on test)

baseline_series = pd.Series(y_test_pred.ravel(), index=y_test_true.index, name='Baseline')
xgb_series = pd.Series(q_hybrid_test, index=y_test_true.index, name='Hybrid_XGB')
lstm_series = pd.Series(np.nan, index=y_test_true.index, name='Hybrid_LSTM')

results_df = pd.DataFrame({
    'Observed': y_test_true,
    'Baseline': baseline_series,
    'Hybrid_XGB': xgb_series,
}, index=y_test_true.index)

# Plot the results
fig = go.Figure()
fig.add_trace(go.Scatter(x=results_df.index, y=results_df['Observed'], mode='lines', name='Observed Discharge', line=dict(width=8)))
fig.add_trace(go.Scatter(x=results_df.index, y=results_df['Baseline'], mode='lines', name='Baseline Model', line=dict(dash='dash', width=2)))
fig.add_trace(go.Scatter(x=results_df.index, y=results_df['Hybrid_XGB'], mode='lines', name='Hybrid XGBoost Model'))

fig.update_layout(title='Model Prediction Performance on Test Data',
                  xaxis_title='Date',
                  yaxis_title='Discharge (m³/s)',
                  legend_title='Models')
fig.show()

# %%
# Cell 14 - Feature Importance from XGBoost
plt.figure(figsize=(10, 12))
xgb.plot_importance(xgb2, max_num_features=20, height=0.8)
plt.title('XGBoost Feature Importance')
plt.show()
